# %%
## Packages
# system
import os
import math
# data wrangling
import numpy as np
import pandas as pd
from scipy import stats
from dfply import *
import statistics
# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# models
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, KFold, StratifiedKFold, cross_val_score 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, recall_score, make_scorer, accuracy_score, balanced_accuracy_score, f1_score, precision_score, roc_auc_score
from sklearn.preprocessing import normalize, StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
## Settings
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) 
pd.set_option('display.width', 1000)
# Out:
# /Users/luyu/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/luyu/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Data Import

# %%
df = pd.read_csv('../processed_data/provider_final_new.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df = df.set_index('Provider')
display(df.shape)

# Make dummies
encode_cols = df[~df.applymap(np.isreal)].dropna(axis=1).columns.to_list()
print(encode_cols)
df[encode_cols[2:]] = df[encode_cols[2:]].applymap(lambda x: 1 if x.lower() == 'yes' else 0)
dummies = pd.get_dummies(df['Serves'],prefix='Serves_',drop_first=True)
df_dum = pd.concat([df.drop('Serves',axis=1),dummies],axis=1)
display(df_dum.shape)

# this is for pos_label for precision & recall for gridsearchcv
df_dum['PotentialFraud'] = np.where(df_dum['PotentialFraud']=='Yes', 1, 0)
# Out:
# (5410, 46)
# ['PotentialFraud', 'Serves', 'DupClaim_IP', 'DupClaimMultiState_IP', 'DupClaimMultiProvider_IP', 'DupClaimMultiStartDt_IP', 'DupClaim_OP', 'DupClaimMultiState_OP', 'DupClaimMultiProvider_OP', 'DupClaimMultiStartDt_OP']
# (5410, 47)

# %% [markdown]
# ## SVM

# %% [markdown]
# ### train-test-split

# %%
# remove Duration MedianIP
df_dum_drop = df_dum.drop(['DurationMedianIP'], axis=1)

# train-test-split
x = df_dum_drop.drop(['PotentialFraud'], axis = 1)
y = df_dum_drop.PotentialFraud
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=4, stratify=y)

# upsampling by SMOTE
sm = SMOTE(random_state=4)
xtrain, ytrain = sm.fit_sample(xtrain, ytrain)
# Out:
# /Users/luyu/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
svc = SVC()

# svc_params = [{'kernel':['linear', 'poly', 'rbf'], 'C':[0.1, 1, 10] , 'degree':[2,3,4]}]
# svc_params = [{'kernel':['linear'], 'C':[0.1, 1, 10]]
svc_params = [{'kernel':['poly', 'rbf', 'sigmoid'], 'C':[0.01, 0.1, 1, 10, 100], 'degree':[3,4,5,6,7,8]}]

kf = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 4) # cv = 5

scores = { 'recall': make_scorer(recall_score, pos_label = 1, average = 'binary'), 
          'f1': make_scorer(f1_score, pos_label = 1, average = 'binary'), # use binary not weighted
         'precision': make_scorer(precision_score, pos_label = 1, average = 'binary'),
         'accuracy': make_scorer(accuracy_score), # not use balanced_accurarcy_score
         'specificity': make_scorer(recall_score, pos_label = 0, average = 'binary'), 
         'roc_auc_score': make_scorer(roc_auc_score, average = 'macro')
         }


svc_grid_nln = GridSearchCV(estimator=svc, param_grid=svc_params, return_train_score=True, 
                       cv = kf, verbose=2, scoring=scores, refit=False)

# %time svc_grid_nln.fit(xtrain, ytrain)
# Out:
# Fitting 10 folds for each of 90 candidates, totalling 900 fits
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   4.6s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.7s remaining:    0.0s
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   5.3s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   4.0s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   3.9s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   3.2s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   3.4s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   3.1s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   4.3s
# [CV] C=0.01, degree=3, kernel=poly ...................................
# [CV] .................... C=0.01, degree=3, kernel=poly, total=   6.4s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   5.5s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   5.6s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   3.5s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   4.5s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   3.9s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   3.5s
# [CV] C=0.01, degree=3, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=3, kernel=rbf, total=   4.7s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.4s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   3.7s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.8s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.5s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.8s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.4s
# [CV] C=0.01, degree=3, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=3, kernel=sigmoid, total=   2.3s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   4.1s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   3.6s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   4.3s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   3.8s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   3.9s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   4.0s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   3.8s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   7.1s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   5.0s
# [CV] C=0.01, degree=4, kernel=poly ...................................
# [CV] .................... C=0.01, degree=4, kernel=poly, total=   4.6s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.2s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.4s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.6s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   5.2s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   5.3s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.9s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.5s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=4, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=4, kernel=rbf, total=   4.4s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   6.3s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   4.7s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   5.3s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   5.5s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   4.6s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   3.0s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=4, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=4, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   5.5s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   5.3s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.9s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   5.9s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.5s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.8s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   5.1s
# [CV] C=0.01, degree=5, kernel=poly ...................................
# [CV] .................... C=0.01, degree=5, kernel=poly, total=   4.6s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.2s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.7s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.3s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.5s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   5.1s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   3.9s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   4.7s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   3.8s
# [CV] C=0.01, degree=5, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=5, kernel=rbf, total=   3.9s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.5s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   3.0s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   3.0s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.9s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.9s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.7s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=5, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=5, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   4.8s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   5.4s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   5.2s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   5.9s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   3.9s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   4.3s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   5.0s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   4.9s
# [CV] C=0.01, degree=6, kernel=poly ...................................
# [CV] .................... C=0.01, degree=6, kernel=poly, total=   4.6s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.2s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   5.2s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   6.7s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.9s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.7s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.6s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   4.1s
# [CV] C=0.01, degree=6, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=6, kernel=rbf, total=   3.4s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.2s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.5s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.0s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.0s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.2s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.4s
# [CV] C=0.01, degree=6, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=6, kernel=sigmoid, total=   2.9s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   3.9s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   4.3s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   4.2s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   5.1s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   5.8s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   5.0s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   4.6s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   5.1s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   5.6s
# [CV] C=0.01, degree=7, kernel=poly ...................................
# [CV] .................... C=0.01, degree=7, kernel=poly, total=   4.3s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   4.6s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.3s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   4.8s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.7s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.8s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.5s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.6s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=7, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=7, kernel=rbf, total=   3.4s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.2s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   3.0s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   3.1s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   5.2s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.7s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.5s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.5s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.4s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.8s
# [CV] C=0.01, degree=7, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=7, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.8s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.5s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.5s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.9s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.4s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.7s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.0s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.2s
# [CV] C=0.01, degree=8, kernel=poly ...................................
# [CV] .................... C=0.01, degree=8, kernel=poly, total=   4.4s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   3.3s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   3.5s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   3.3s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   5.9s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   4.2s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   2.9s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   3.7s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   3.5s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   4.0s
# [CV] C=0.01, degree=8, kernel=rbf ....................................
# [CV] ..................... C=0.01, degree=8, kernel=rbf, total=   2.9s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.2s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.3s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.4s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   3.2s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.9s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.7s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.6s
# [CV] C=0.01, degree=8, kernel=sigmoid ................................
# [CV] ................. C=0.01, degree=8, kernel=sigmoid, total=   2.6s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   3.9s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   3.4s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   3.1s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   2.8s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   3.9s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   3.7s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   4.5s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   4.3s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   5.8s
# [CV] C=0.1, degree=3, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=3, kernel=poly, total=   7.2s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   2.7s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   3.2s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   4.0s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   2.9s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   3.7s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   3.8s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   4.2s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   2.8s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   2.6s
# [CV] C=0.1, degree=3, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=3, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.7s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.8s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   2.3s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   2.3s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.7s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.5s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.6s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.6s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.5s
# [CV] C=0.1, degree=3, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=3, kernel=sigmoid, total=   1.5s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   3.1s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   7.7s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   5.8s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   3.8s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   5.3s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   4.3s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   4.5s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   4.6s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   4.6s
# [CV] C=0.1, degree=4, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=4, kernel=poly, total=   4.8s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   2.9s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.4s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.5s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.1s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.7s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.0s
# [CV] C=0.1, degree=4, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=4, kernel=rbf, total=   3.0s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.0s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.8s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.4s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.4s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.2s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=4, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=4, kernel=sigmoid, total=   1.9s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   5.0s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.9s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.7s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.4s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.4s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.0s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.1s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.5s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.7s
# [CV] C=0.1, degree=5, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=5, kernel=poly, total=   4.7s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.2s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   4.1s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.6s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   8.6s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   5.7s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.5s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.4s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.4s
# [CV] C=0.1, degree=5, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=5, kernel=rbf, total=   3.1s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.2s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   1.9s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.0s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.2s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   1.9s
# [CV] C=0.1, degree=5, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=5, kernel=sigmoid, total=   1.9s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.5s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.2s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.0s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.0s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.0s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   4.8s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   6.3s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   5.8s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   4.4s
# [CV] C=0.1, degree=6, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=6, kernel=poly, total=   4.7s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   4.7s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   2.9s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.0s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   2.9s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.1s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.0s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.2s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=6, kernel=rbf .....................................
# [CV] ...................... C=0.1, degree=6, kernel=rbf, total=   3.3s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.2s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   1.9s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.2s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   3.4s
# [CV] C=0.1, degree=6, kernel=sigmoid .................................
# [CV] .................. C=0.1, degree=6, kernel=sigmoid, total=   2.1s
# [CV] C=0.1, degree=7, kernel=poly ....................................
# [CV] ..................... C=0.1, degree=7, kernel=poly, total=   5.6s
# [CV] C=0.1, degree=7, kernel=poly ....................................
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_scorer.py in _cached_call(cache, estimator, method, *args, **kwargs)
#      55     try:
# ---> 56         return cache[method]
#      57     except KeyError:
#
# KeyError: 'predict'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     561         score_time = time.time() - start_time - fit_time
#     562         if return_train_score:
# --> 563             train_scores = _score(estimator, X_train, y_train, scorer)
#     564     if verbose > 2:
#     565         if isinstance(test_scores, dict):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer)
#     605         scores = scorer(estimator, X_test)
#     606     else:
# --> 607         scores = scorer(estimator, X_test, y_test)
#     608
#     609     error_msg = ("scoring must return a number, got %s (%s) "
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_scorer.py in __call__(self, estimator, *args, **kwargs)
#      86             if isinstance(scorer, _BaseScorer):
#      87                 score = scorer._score(cached_call, estimator,
# ---> 88                                       *args, **kwargs)
#      89             else:
#      90                 score = scorer(estimator, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_scorer.py in _score(self, method_caller, estimator, X, y_true, sample_weight)
#     204         """
#     205
# --> 206         y_pred = method_caller(estimator, "predict", X)
#     207         if sample_weight is not None:
#     208             return self._sign * self._score_func(y_true, y_pred,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_scorer.py in _cached_call(cache, estimator, method, *args, **kwargs)
#      56         return cache[method]
#      57     except KeyError:
# ---> 58         result = getattr(estimator, method)(*args, **kwargs)
#      59         cache[method] = result
#      60         return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in predict(self, X)
#     613             y = np.argmax(self.decision_function(X), axis=1)
#     614         else:
# --> 615             y = super().predict(X)
#     616         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     617
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in predict(self, X)
#     333         X = self._validate_for_predict(X)
#     334         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 335         return predict(X)
#     336
#     337     def _dense_predict(self, X):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _dense_predict(self, X)
#     355             self._probA, self._probB, svm_type=svm_type, kernel=kernel,
#     356             degree=self.degree, coef0=self.coef0, gamma=self._gamma,
# --> 357             cache_size=self.cache_size)
#     358
#     359     def _sparse_predict(self, X):
#
# KeyboardInterrupt:

# %%
svc_grid_nln_scores = pd.DataFrame({'params': svc_grid_nln.cv_results_['params'], 
              'mean_validation_recall': svc_grid_nln.cv_results_['mean_test_recall'],
              'mean_train_recall': svc_grid_nln.cv_results_['mean_train_recall'],
              'mean_validation_f1': svc_grid_nln.cv_results_['mean_test_f1'],
              'mean_train_f1': svc_grid_nln.cv_results_['mean_train_f1'],
              'mean_validation_precision': svc_grid_nln.cv_results_['mean_test_precision'],
              'mean_train_precision': svc_grid_nln.cv_results_['mean_train_precision'],
              'mean_validation_accuracy': svc_grid_nln.cv_results_['mean_test_accuracy'],
              'mean_train_accuracy': svc_grid_nln.cv_results_['mean_train_accuracy'],
              'mean_validation_specificity': svc_grid_nln.cv_results_['mean_test_specificity'],
              'mean_train_specificity': svc_grid_nln.cv_results_['mean_train_specificity'], 
              'mean_validation_roc_auc_score': svc_grid_nln.cv_results_['mean_test_roc_auc_score'],
              'mean_train_roc_auc_score': svc_grid_nln.cv_results_['mean_train_roc_auc_score']
             })
# svc_grid_nln_scores.to_csv('../output/svc_grid_nln_scores_dropDurationMedianIP.csv')
svc_grid_nln_scores

# %%
svc_grid_nln_scores_validation = svc_grid_nln_scores[svc_grid_nln_scores.columns[svc_grid_nln_scores.columns.str.contains('validation')]]
display(svc_grid_nln_scores_validation)
svc_grid_nln_scores_train = svc_grid_nln_scores[svc_grid_nln_scores.columns[svc_grid_nln_scores.columns.str.contains('train')]]
display(svc_grid_nln_scores_train)

# %%
# plot validation scores
plt.figure(figsize=(8,6))
sns.lineplot(data =svc_grid_nln_scores_validation)
plt.legend( loc=5) #bbox_to_anchor=(1.05,1)
plt.xlabel('model#', fontsize=18)
plt.ylabel('score', fontsize=18)
plt.title('SVC NonLinear Grid Search Model Scores: Validation', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# plt.savefig('../output/svc_grid_nln_validation_allscore_dropDurationMedianIP_cv10.png', bbox_inches='tight')
# plt.xlim(180, 190)
# plt.savefig('../output/svc_grid_nln_validation_allscore_dropDurationMedianIP_cv10_zoom.png', bbox_inches='tight')

# %%
# plot train scores
plt.figure(figsize=(8,6))
sns.lineplot(data =svc_grid_nln_scores_train)
plt.legend( loc=5) #bbox_to_anchor=(1.05,1)
plt.xlabel('model#', fontsize=18)
plt.ylabel('score', fontsize=18)
plt.title('SVC NonLinear Grid Search Model Scores: Train', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# plt.savefig('../output/svc_grid_nln_train_allscore_dropDurationMedianIP_cv10.png', bbox_inches='tight')
# plt.xlim(180, 190)
# plt.savefig('../output/svc_grid_nln_train_allscore_dropDurationMedianIP_cv10_zoom.png', bbox_inches='tight')

# %%
svc_grid_nln_scores['tvdiff_recall'] = abs(svc_grid_nln_scores['mean_validation_recall'] - svc_grid_nln_scores['mean_train_recall'])
lof_row = svc_grid_nln_scores['tvdiff_recall'].idxmin()
display(svc_grid_nln_scores_validation.iloc[[lof_row]])
display(svc_grid_nln_scores_train.iloc[[lof_row]])
display(svc_grid_nln_scores.params[lof_row])

# %%
best_row =svc_grid_nln_scores.mean_validation_recall.idxmax()
worst_row =svc_grid_nln_scores.mean_validation_recall.idxmin()
print('best RF row number', best_row)
print('worst RF row number', worst_row)
print('best RF coarse',svc_grid_nln_scores.params[best_row])
display(gbc_grid_fine_scores[gbc_grid_fine_scores.columns[gbc_grid_fine_scores.columns.str.contains('mean_validation')]].iloc[[best_row,]])
display(gbc_grid_fine_scores[gbc_grid_fine_scores.columns[gbc_grid_fine_scores.columns.str.contains('mean_train')]].iloc[[best_row,]])

svc_params = [{'kernel':['poly', 'rbf', 'sigmoid'], 'C':[0.01, 0.1, 1, 10, 100], 'degree':[3,4,5,6,7,8]}]

svc_grid_nln_kernel =svc_grid_nln_scores.params[best_row]['kernel']
svc_grid_nln_C =svc_grid_nln_scores.params[best_row]['C']
svc_grid_nln_degree =svc_grid_nln_scores.params[best_row]['degree']

print(svc_grid_nln_kernel, svc_grid_nln_C, svc_grid_nln_degree)

# %%
# scores
svc_nln_best_fine = SVC(kernel=el=el = svc_grid_nln_kernel, C = svc_grid_nln_C, degree = svc_grid_nln_degree)
svc_nln_best_fine.fit(xtrain, ytrain)

svc_nln_best_train = svc_nln_best_fine.score(xtrain, ytrain)
svc_nln_best_test = svc_nln_best_fine.score(xtest, ytest)
print('svc nln coarse best train', round(svc_nln_best_train, 4)) 
print('svc nln coarse best test', round(svc_nln_best_test, 4))
